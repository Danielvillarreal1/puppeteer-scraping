# %%
import mysql.connector
import pandas as pd 
import requests

my_conn = mysql.connector.connect(
      host="172.19.0.2",
      user="root",
      passwd="root",
      database="booki"
    )
####### end of connection ####
my_data = pd.read_sql("SELECT * FROM hotel",my_conn)
print(my_data)
# Out:
#     ID                                Name_hotel    Prices  \
# 0    1     Los Cerros del Chaltén Boutique Hotel  $ 35.338
# 1    2        Howard Johnson Hotel Piedras Moras  $ 20.065
# 2    3                          Benitez Hostería   $ 7.795
# 3    4                     Hotel Plaza Bariloche   $ 8.518
# 4    5        Grand Hotel - Sierra De La Ventana  $ 16.885
# 5    6                       Himmel Blau Rentals  $ 13.767
# 6    7                              Hotel Amayal  $ 12.013
# 7    8                                La Comarca  $ 17.323
# 8    9                                 SMA FLATS  $ 12.342
# 9   10                       Hotel Tierra Gaucha  $ 15.433
# 10  11  Chalet Suisse Posada & SPA - Adults only  $ 19.567
# 11  12   Esplendor by Wyndham Buenos Aires Tango  $ 25.438
# 12  13                      Regente Palace Hotel  $ 30.241
# 13  14                Palacio Paz Boutique Hotel  $ 18.593
# 14  15           Villa La Font Apart Hotel & Spa  $ 15.590
# ...
